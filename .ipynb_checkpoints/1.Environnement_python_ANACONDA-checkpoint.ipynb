# %% [markdown]
# # <span style='color:SteelBlue'>EXPLICATIONS pour commencer</span>

# %% [markdown]
# ## <span style='color:SteelBlue'>Présentation</span>
# ### Dans ce notebook (Jupyter) de présentation, nous verrons le déroulement des exercices et des évaluations informatiques qui vous seront proposés, dans un environnement anaconda.

# %% [markdown]
# ## <span style='color:SteelBlue'>Environnement python anaconda - Notebooks Jupyter </span>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Anaconda est une distribution scientifique de Python : c’est-à-dire qu’en installant Anaconda, vous aurez un __environnement python complet__ et prêt à l’emploi.
# - Anaconda est basé sur un écosystème totalement __open-source.__
#
# - Anaconda contient Jupyter, qui est essentiellement une combinaison entre un IDE et un serveur pour exécuter vos Notebooks. Le nom __Jupyter__ est un acronyme qui représente les trois langues pour lesquelles il a été conçu à l’origine : __JUlia, PYThon et R.__
#
# - __Les Notebooks Jupyter,__ comme vous pouvez le constater,  contiennent __à la fois du code et des éléments de présentation__, tels que des images ou du texte, réunis en un seul endroit.

# %% [markdown]
# Pour installer Anaconda : https://www.anaconda.com/products/distribution

# %% [markdown]
# - Une fois Anaconda installé, vous pouvez ouvrir un notebook jupyter.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style='color:SteelBlue'>Présentation du canevas utilisé dans les notebooks</span>

# %% [markdown]
# __Voici la structure qui vous sera proposée dans les notebooks:__

# %% [markdown]
# ## <span style='background:Thistle'>1. Sommaire</span>

# %% [markdown]
# - Un sommaire, avec des liens pour aller facilement à n'importe quelle étape du notebook.

# %%
import jyquickhelper
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
# ...

# %% [markdown]
# ## <span style='background:Thistle'>2. A propos du jeu de données</span>

# %% [markdown]
# - Une description du jeu de données, de son contenu

# %% [markdown]
# ## <span style='background:Thistle'>3. Chargement des librairies</span>

# %% [markdown]
# - Chargement des librairies nécessaires à l'exécution du notebook

# %% [markdown]
# ## <span style='background:Thistle'>4. Mise en oeuvre Machine Learning </span>
# - Exemple : Résoudre une tâche de classification, étape par étape, grâce aux MLP
# - Vous trouverez ensuite en bleu toutes les étapes à suivre pour résoudre la tâche demandée.

# %% [markdown]
# ### <span style='background:PowderBlue'>ETAPE 1 : Chargement du jeu de données</span>

# %% [markdown]
# ### <span style='background:PowderBlue'>ETAPE 2 : Pré-traitement du jeu de données</span>

# %% [markdown]
# ### <span style='background:PowderBlue'>ETAPE 3 : Modélisation avec un algorithme de Machine Learning

# %% [markdown]
# ### <span style='background:PowderBlue'>ETAPE 4 : Entraînement du modèle</span>

# %% [markdown]
# ### <span style='background:PowderBlue'>ETAPE 5 : Evaluer le modèle</span>

# %% [markdown]
# ### Vous êtes maintenant prêts à vous lancer dans le cours sur le Machine Learning !

# %% [markdown]
# ### C'est parti !!!
